# %% [markdown]
# MACHINE LEARNING NYA SEDERHANA
# PENENTUAN GAJI KARYAWAN

# %%
import pandas as pd

# %%
df = pd.read_csv("Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
X = df.iloc[:, :1]
y = df.iloc[:, 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
import matplotlib.pyplot as plt 
plt.scatter(X_train, y_train, color="green")
plt.plot(X_train, regressor.predict(X_train), color="red")
plt.title("Years Experience VS Salary")
plt.xlabel("Years Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X_test, y_test, color="green")
plt.plot(X_train, regressor.predict(X_train), color="red")
plt.title("years experience vs salary")
plt.xlabel("years experience")
plt.ylabel("salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# MEMBUAT PREDIKSI BARU

# %%
import numpy as np
salary_pred = regressor.predict([[30]])
print ("Gaji menurut pengalaman adalah : $", np.around(salary_pred))
# Out:
# Gaji menurut penglaman adalah : $ [307194.]
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
